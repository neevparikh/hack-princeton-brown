# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing as pp
from sklearn.neural_network import MLPClassifier as mlc
from sklearn.model_selection import train_test_split
import pickle

df = pd.read_csv("train_feat_df.csv").dropna()
del df["Unnamed: 0"]
del df["Bachelor's Degree"]
df["label"] = pd.Series(np.ones((df["population"].count(),), dtype=int))

fake = pd.read_csv("fakefuck.csv")
del fake["Unnamed: 0"]
fake["label"] = pd.Series(np.zeros((fake["population"].count(),), dtype=int))

merged = pd.concat([df, fake], sort=False).sample(frac=1.0).reset_index(drop=True)

t_df = merged[list(merged.columns)[26:69]]

l = list(merged.columns)[1:26]
l.extend(list(merged.columns)[70:-1])
s_df = merged[l]

labels = merged["label"]

s_x = pp.scale(s_df.values)
X = np.concatenate((s_x, t_df.values), axis=1)

y = labels.values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

clf = mlc(
    hidden_layer_sizes=(1,),
    activation="relu",
    solver="adam",
    alpha=0.0001,
    batch_size="auto"
    ) 
print("Training...")
trained_clf = clf.fit(X_train, y_train)
y_prob = clf.predict_proba(X_test)
y_pred = clf.predict(X_test)
print(y_pred, y_test)
# score = trained_clf.score(X_test, y_test)
score = sum([1 for sample in y_pred if sample in y_test])/len(y_test)
print("Score: ", score)
print("Pickling...")
pickle.dump(trained_clf, open("model.pkl", "wb"))
# Out:
# Training...
# [1 1 0 ... 0 1 0] [1 1 0 ... 0 1 0]
# Score:  1.0
# Pickling...
# /Users/neevparikh/Projects/HackPrinceton/virt/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
l = len(y_test)
for i in range(len(y_test)):
    print("       ",y_test[i], y_pred[i], y_prob[i])
# Out:
#         1 1 [2.14687996e-05 9.99978531e-01]
#         1 1 [1.40150840e-05 9.99985985e-01]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         1 1 [1.69829979e-06 9.99998302e-01]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         1 1 [7.36421235e-06 9.99992636e-01]
#         0 0 [0.97088523 0.02911477]
#         1 1 [2.55822201e-06 9.99997442e-01]
#         0 0 [0.97088523 0.02911477]
#         0 0 [0.97088523 0.02911477]
#         1 1 [1.31978679e-06 9.99998680e-01]
#         0 0 [0.97088523 0.02911477]
#         1 1 [3.63164666e-05 9.99963684e-01]
#         0 0 [0.97088523 0.02911477]
#         1 1 [1.07073485e-05 9.99989293e-01]
#         1 1 [1.00930090e-06 9.99998991e-01]
#         0 0 [0.97088523 0.02911477]
# ...

# %%
fake.describe().transpose()
# Out:
#                                            count        mean           std  \
# population_density                        5000.0  50287.5682  23167.615824
# median_household_income                   5000.0  52509.0424  10088.225374
# Male                                      5000.0  35923.3854  12772.646275
# Female                                    5000.0  12196.8840   3571.164320
# White                                     5000.0  43209.2618  14630.414841
# Black Or African American                 5000.0  21553.2362   8443.773619
# American Indian Or Alaskan Native         5000.0    325.9724    225.896694
# Asian                                     5000.0   1298.2970    697.588270
# Native Hawaiian & Other Pacific Islander  5000.0     84.1362     59.780271
# Other Race                                5000.0   2516.2850   1606.661984
# < $25,000                                 5000.0   6257.0208   1679.136453
# ...

# %%
df.describe().transpose()
# Out:
#                                            count          mean           std  \
# population_density                        3612.0   5953.522425   8502.509606
# median_household_income                   3612.0  46494.491141  22632.238297
# Male                                      3612.0  10144.896733   7840.411591
# Female                                    3612.0  10082.105205   8234.623698
# White                                     3612.0  12640.082503  10896.019073
# Black Or African American                 3612.0   4242.145349   5322.215968
# American Indian Or Alaskan Native         3612.0    200.426080    602.317801
# Asian                                     3612.0    873.378738   1553.369255
# Native Hawaiian & Other Pacific Islander  3612.0     32.146456    141.142370
# Other Race                                3612.0   1596.492802   3909.970044
# < $25,000                                 3612.0   2435.648948   1917.981422
# ...

# %%
fake
# Out:
#       population_density  median_household_income   Male  Female  White  \
# 0                  38375                    51443  28160   14740  55973
# 1                  54092                    37948  49562   15573  50167
# 2                  19886                    45128  38114    8985  34677
# 3                  89233                    37416  40852    5979  40001
# 4                  71779                    49921  54241   14746  57354
# 5                  43610                    56309  16015   10048  43262
# 6                  30522                    68971  56168    6046  37850
# 7                  88262                    59521  57924   14570  24197
# 8                  84535                    59473  58246   15150  38485
# 9                  76122                    48767  57449   14871  50556
# 10                 61753                    41414  54815   16531  59871
# 11                 59125                    56935  24350   10743  50803
# ...

# %%
df
# Out:
#       population_density  median_household_income   Male  Female  White  \
# 0                    147                    56098  34599   33592  40048
# 1                    130                    30625  21145   20963  24717
# 2                   8320                    64093  13839    2954   8704
# 3                   9850                    97158  17521   17772  28052
# 4                    808                    39659   5383    5357   7556
# 5                   3153                    77156  11025   12233  20392
# 6                   5247                    61188  18103   21951   1649
# 7                   1924                    36598  13919   14692  23706
# 8                      9                    58094    543     474    960
# 9                    842                    50526  18443   20013  25811
# 10                  3158                    65420  45980   48402  52621
# 11                  9989                    85672  19847   21509  12288
# ...
